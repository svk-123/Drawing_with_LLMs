# %%
import kagglehub
kagglehub.login()

# %%
# Replace with path to directory containing model files.
LOCAL_MODEL_DIR = './lora/Qwen25_7B_Instruct_lora_fp16_r256_s2000_i2000_msl2048/'

MODEL_SLUG = 'Qwen2.5_7B_Instruct_LoRA4bit_16bit_merged' # Replace with model slug.

# Learn more about naming model variations at
# https://www.kaggle.com/docs/models#name-model.
VARIATION_SLUG = '01' # Replace with variation slug.

kagglehub.model_upload(
  handle = f"vinothkumarsekar89/{MODEL_SLUG}/transformers/{VARIATION_SLUG}",
  local_model_dir = LOCAL_MODEL_DIR,
  version_notes = 'Update 2025-04-18')
# Out:
# Uploading Model https://www.kaggle.com/models/vinothkumarsekar89/Qwen2.5_7B_Instruct_LoRA4bit_16bit_merged/transformers/01 ...
# Model 'Qwen2.5_7B_Instruct_LoRA4bit_16bit_merged' does not exist or access is forbidden for user 'vinothkumarsekar89'. Creating or handling Model...
# Model 'Qwen2.5_7B_Instruct_LoRA4bit_16bit_merged' Created.
# Starting upload for file ./lora/Qwen25_7B_Instruct_lora_fp16_r256_s2000_i2000_msl2048/merges.txt
# Uploading: 100%|████████████████████████████| 1.67M/1.67M [00:01<00:00, 857kB/s]
# Upload successful: ./lora/Qwen25_7B_Instruct_lora_fp16_r256_s2000_i2000_msl2048/merges.txt (2MB)
# Starting upload for file ./lora/Qwen25_7B_Instruct_lora_fp16_r256_s2000_i2000_msl2048/tokenizer_config.json
# Uploading: 100%|███████████████████████████| 7.36k/7.36k [00:00<00:00, 9.36kB/s]
# Upload successful: ./lora/Qwen25_7B_Instruct_lora_fp16_r256_s2000_i2000_msl2048/tokenizer_config.json (7KB)
# ...
