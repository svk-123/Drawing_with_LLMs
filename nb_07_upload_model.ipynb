# %%
import kagglehub
kagglehub.login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…

# %%
# Replace with path to directory containing model files.
LOCAL_MODEL_DIR = './lora/Qwen3_4B_lora_fp16_r256_s15000_i2000_msl2048/'

MODEL_SLUG = 'qwen3-4b-lora-svg-generation' # Replace with model slug.

# Learn more about naming model variations at
# https://www.kaggle.com/docs/models#name-model.
VARIATION_SLUG = '01' # Replace with variation slug.

kagglehub.model_upload(
  handle = f"vinothkumarsekar89/{MODEL_SLUG}/transformers/{VARIATION_SLUG}",
  local_model_dir = LOCAL_MODEL_DIR,
  version_notes = 'Update 2025-05-05')
# Out:
# Uploading Model https://www.kaggle.com/models/vinothkumarsekar89/qwen3-4b-lora-svg-generation/transformers/01 ...
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.11), please consider upgrading to the latest version (0.3.12).
# Starting upload for file ./lora/Qwen3_4B_lora_fp16_r256_s15000_i2000_msl2048/merges.txt
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.11), please consider upgrading to the latest version (0.3.12).
# Uploading: 100%|████████████████████████████| 1.67M/1.67M [00:03<00:00, 551kB/s]
# Upload successful: ./lora/Qwen3_4B_lora_fp16_r256_s15000_i2000_msl2048/merges.txt (2MB)
# Starting upload for file ./lora/Qwen3_4B_lora_fp16_r256_s15000_i2000_msl2048/tokenizer_config.json
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.11), please consider upgrading to the latest version (0.3.12).
# Uploading: 100%|███████████████████████████| 10.3k/10.3k [00:01<00:00, 8.31kB/s]
# Upload successful: ./lora/Qwen3_4B_lora_fp16_r256_s15000_i2000_msl2048/tokenizer_config.json (10KB)
# Starting upload for file ./lora/Qwen3_4B_lora_fp16_r256_s15000_i2000_msl2048/model-00001-of-00002.safetensors
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.11), please consider upgrading to the latest version (0.3.12).
# Uploading: 100%|███████████████████████████| 4.97G/4.97G [33:41<00:00, 2.46MB/s]
# Upload successful: ./lora/Qwen3_4B_lora_fp16_r256_s15000_i2000_msl2048/model-00001-of-00002.safetensors (5GB)
# Starting upload for file ./lora/Qwen3_4B_lora_fp16_r256_s15000_i2000_msl2048/special_tokens_map.json
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.11), please consider upgrading to the latest version (0.3.12).
# Uploading: 100%|█████████████████████████████████| 614/614 [00:01<00:00, 585B/s]
# Upload successful: ./lora/Qwen3_4B_lora_fp16_r256_s15000_i2000_msl2048/special_tokens_map.json (614B)
# Starting upload for file ./lora/Qwen3_4B_lora_fp16_r256_s15000_i2000_msl2048/tokenizer.json
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.11), please consider upgrading to the latest version (0.3.12).
# Uploading: 100%|███████████████████████████| 11.4M/11.4M [00:09<00:00, 1.22MB/s]
# Upload successful: ./lora/Qwen3_4B_lora_fp16_r256_s15000_i2000_msl2048/tokenizer.json (11MB)
# Starting upload for file ./lora/Qwen3_4B_lora_fp16_r256_s15000_i2000_msl2048/model.safetensors.index.json
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.11), please consider upgrading to the latest version (0.3.12).
# Uploading: 100%|███████████████████████████| 32.8k/32.8k [00:01<00:00, 32.3kB/s]
# Upload successful: ./lora/Qwen3_4B_lora_fp16_r256_s15000_i2000_msl2048/model.safetensors.index.json (32KB)
# Starting upload for file ./lora/Qwen3_4B_lora_fp16_r256_s15000_i2000_msl2048/model-00002-of-00002.safetensors
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.11), please consider upgrading to the latest version (0.3.12).
# Uploading: 100%|███████████████████████████| 3.08G/3.08G [14:19<00:00, 3.58MB/s]
# Upload successful: ./lora/Qwen3_4B_lora_fp16_r256_s15000_i2000_msl2048/model-00002-of-00002.safetensors (3GB)
# Starting upload for file ./lora/Qwen3_4B_lora_fp16_r256_s15000_i2000_msl2048/added_tokens.json
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.11), please consider upgrading to the latest version (0.3.12).
# Uploading: 100%|█████████████████████████████████| 707/707 [00:01<00:00, 388B/s]
# Upload successful: ./lora/Qwen3_4B_lora_fp16_r256_s15000_i2000_msl2048/added_tokens.json (707B)
# Starting upload for file ./lora/Qwen3_4B_lora_fp16_r256_s15000_i2000_msl2048/vocab.json
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.11), please consider upgrading to the latest version (0.3.12).
# Uploading: 100%|████████████████████████████| 2.78M/2.78M [00:03<00:00, 925kB/s]
# Upload successful: ./lora/Qwen3_4B_lora_fp16_r256_s15000_i2000_msl2048/vocab.json (3MB)
# Starting upload for file ./lora/Qwen3_4B_lora_fp16_r256_s15000_i2000_msl2048/config.json
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.11), please consider upgrading to the latest version (0.3.12).
# Uploading: 100%|█████████████████████████████████| 785/785 [00:00<00:00, 824B/s]
# Upload successful: ./lora/Qwen3_4B_lora_fp16_r256_s15000_i2000_msl2048/config.json (785B)
# Starting upload for file ./lora/Qwen3_4B_lora_fp16_r256_s15000_i2000_msl2048/generation_config.json
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.11), please consider upgrading to the latest version (0.3.12).
# Uploading: 100%|█████████████████████████████████| 237/237 [00:01<00:00, 230B/s]
# Upload successful: ./lora/Qwen3_4B_lora_fp16_r256_s15000_i2000_msl2048/generation_config.json (237B)
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.11), please consider upgrading to the latest version (0.3.12).
# Your model instance has been created.
# Files are being processed...
# See at: https://www.kaggle.com/models/vinothkumarsekar89/qwen3-4b-lora-svg-generation/transformers/01
