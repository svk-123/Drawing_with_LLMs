# %%
import kagglehub
kagglehub.login()

# %%
# Replace with path to directory containing model files.
LOCAL_MODEL_DIR = './lora/lora_16bit_merged_3b_v1/'

MODEL_SLUG = 'llama_3p2_3b_svg_16bit_merged' # Replace with model slug.

# Learn more about naming model variations at
# https://www.kaggle.com/docs/models#name-model.
VARIATION_SLUG = '01' # Replace with variation slug.

kagglehub.model_upload(
  handle = f"vinothkumarsekar89/{MODEL_SLUG}/transformers/{VARIATION_SLUG}",
  local_model_dir = LOCAL_MODEL_DIR,
  version_notes = 'Update 2025-03-27')
# Out:
# Uploading Model https://www.kaggle.com/models/vinothkumarsekar89/llama_3p2_3b_svg_16bit_merged/transformers/01 ...
# Model 'llama_3p2_3b_svg_16bit_merged' does not exist or access is forbidden for user 'vinothkumarsekar89'. Creating or handling Model...
# Model 'llama_3p2_3b_svg_16bit_merged' Created.
# Starting upload for file ./lora/lora_16bit_merged_3b_v1/tokenizer_config.json
# Uploading: 100%|███████████████████████████| 54.7k/54.7k [00:01<00:00, 30.5kB/s]
# Upload successful: ./lora/lora_16bit_merged_3b_v1/tokenizer_config.json (53KB)
# Starting upload for file ./lora/lora_16bit_merged_3b_v1/model-00001-of-00002.safetensors
# Uploading: 100%|███████████████████████████| 4.97G/4.97G [12:30<00:00, 6.61MB/s]
# Upload successful: ./lora/lora_16bit_merged_3b_v1/model-00001-of-00002.safetensors (5GB)
# Starting upload for file ./lora/lora_16bit_merged_3b_v1/special_tokens_map.json
# Uploading: 100%|█████████████████████████████████| 454/454 [00:00<00:00, 541B/s]
# ...
