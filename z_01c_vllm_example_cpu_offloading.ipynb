# %%
from vllm import LLM, SamplingParams
# Out:
# INFO 04-10 22:38:16 [__init__.py:239] Automatically detected platform cuda.

# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"
os.environ['VLLM_USE_V1'] = '0'
